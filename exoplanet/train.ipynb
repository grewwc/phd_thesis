# %%
import matplotlib.pyplot as plt 
import numpy as np
import os 
import sys 
from astropy.io import fits 
import pandas as pd 
import tensorflow as tf 
sys.path.append("C:/Users/User/dev/kepler")
# %load_ext autoreload
# %autoreload 2
from python_tools.plot import plot, plot1d

# %%
# from config import * 
from models.model import get_model
from models import *
from train import * 
from models.resNet import get_resnet_model
from models.dense import get_dense
from clean_utils.io import * 

img_dir = "C:/Users/User/Desktop/Probation/"
data_dir = 'C:/Users/User/dev/data/train/flux'
feature = 'C:/Users/User/dev/data/train/features/f1.txt'

# %%
(g_train_x, l_train_x, train_y), (g_test_x, l_test_x, test_y), (train_features, test_features) \
        = load_data(more_features=1)

# (g_train_x, l_train_x, train_y), (g_test_x, l_test_x, test_y) \
#         = load_data(more_features=0)
# Out:
# loading data from C:/Users/User/dev/data/train\flux\all_PCs_flux.txt
# finished loading
# loading data from C:/Users/User/dev/data/train\flux\all_Non_PCs_flux.txt
# finished loading
# loading data from C:/Users/User/dev/data/train\flux\local_all_PCs_flux.txt
# finished loading
# loading data from C:/Users/User/dev/data/train\flux\local_all_Non_PCs_flux.txt
# finished loading
# shffuling...
# finised shuffing

# %%
# save the best model
l_test_x.shape, test_y.shape,g_test_x.shape
g_train_x.shape, l_train_x.shape, g_test_x.shape
# Out:
# ((14163, 2001, 1), (14163, 201, 1), (1574, 2001, 1))

# %%
# augment data
aug_g_x, aug_l_x, aug_y, aug_features = augment_data(g_train_x, l_train_x, train_y, train_features)
aug_g_x.shape, aug_y.shape , g_train_x.shape
# Out:
# ((28326, 2001, 1), (28326,), (14163, 2001, 1))

# %%
dense = get_dense()
dense.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0906 22:30:09.016274 15544 deprecation.py:506] From c:\users\user\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 17)]              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               9216
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# last_dropout (Dropout)       (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 798,210
# Trainable params: 798,210
# Non-trainable params: 0
# _________________________________________________________________

# %%
set_lr(dense, 0.4e-3)
dense.fit(aug_features,aug_y, epochs=200, batch_size=128, validation_split=0.2)
# Out:
# set learning rate to 0.00039999998989515007
# Train on 22660 samples, validate on 5666 samples
# Epoch 1/200
# 22660/22660 [==============================] - 1s 55us/sample - loss: 0.2850 - acc: 0.8710 - val_loss: 0.2241 - val_acc: 0.9047
# Epoch 2/200
# 22660/22660 [==============================] - 1s 32us/sample - loss: 0.2337 - acc: 0.9058 - val_loss: 0.2167 - val_acc: 0.9105
# Epoch 3/200
# 22660/22660 [==============================] - 1s 32us/sample - loss: 0.2284 - acc: 0.9082 - val_loss: 0.2180 - val_acc: 0.9121
# Epoch 4/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.2226 - acc: 0.9099 - val_loss: 0.2076 - val_acc: 0.9158
# Epoch 5/200
# 22660/22660 [==============================] - 1s 32us/sample - loss: 0.2166 - acc: 0.9130 - val_loss: 0.2020 - val_acc: 0.9179
# Epoch 6/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.2132 - acc: 0.9138 - val_loss: 0.2005 - val_acc: 0.9165
# Epoch 7/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.2116 - acc: 0.9154 - val_loss: 0.2006 - val_acc: 0.9172
# Epoch 8/200
# 22660/22660 [==============================] - 1s 32us/sample - loss: 0.2089 - acc: 0.9161 - val_loss: 0.2018 - val_acc: 0.9179
# Epoch 9/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.2059 - acc: 0.9173 - val_loss: 0.1952 - val_acc: 0.9200
# Epoch 10/200
# 22660/22660 [==============================] - 1s 32us/sample - loss: 0.2041 - acc: 0.9187 - val_loss: 0.1924 - val_acc: 0.9222
# Epoch 11/200
# 22660/22660 [==============================] - 1s 32us/sample - loss: 0.2031 - acc: 0.9176 - val_loss: 0.1956 - val_acc: 0.9204
# Epoch 12/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.2013 - acc: 0.9188 - val_loss: 0.1902 - val_acc: 0.9245
# Epoch 13/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1989 - acc: 0.9207 - val_loss: 0.1896 - val_acc: 0.9218
# Epoch 14/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1986 - acc: 0.9195 - val_loss: 0.1868 - val_acc: 0.9232
# Epoch 15/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1968 - acc: 0.9221 - val_loss: 0.1869 - val_acc: 0.9232
# Epoch 16/200
# 22660/22660 [==============================] - 1s 32us/sample - loss: 0.1947 - acc: 0.9222 - val_loss: 0.1867 - val_acc: 0.9241
# Epoch 17/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1966 - acc: 0.9219 - val_loss: 0.1856 - val_acc: 0.9253
# Epoch 18/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1933 - acc: 0.9227 - val_loss: 0.1877 - val_acc: 0.9234
# Epoch 19/200
# 22660/22660 [==============================] - 1s 32us/sample - loss: 0.1948 - acc: 0.9225 - val_loss: 0.1847 - val_acc: 0.9257
# Epoch 20/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1930 - acc: 0.9225 - val_loss: 0.1823 - val_acc: 0.9245
# Epoch 21/200
# 22660/22660 [==============================] - 1s 36us/sample - loss: 0.1918 - acc: 0.9234 - val_loss: 0.1837 - val_acc: 0.9248
# Epoch 22/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1902 - acc: 0.9233 - val_loss: 0.1814 - val_acc: 0.9268
# Epoch 23/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1903 - acc: 0.9233 - val_loss: 0.1871 - val_acc: 0.9250
# Epoch 24/200
# 22660/22660 [==============================] - 1s 35us/sample - loss: 0.1885 - acc: 0.9235 - val_loss: 0.1848 - val_acc: 0.9234
# Epoch 25/200
# 22660/22660 [==============================] - 1s 32us/sample - loss: 0.1884 - acc: 0.9236 - val_loss: 0.1796 - val_acc: 0.9266
# Epoch 26/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1881 - acc: 0.9238 - val_loss: 0.1796 - val_acc: 0.9268
# Epoch 27/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1877 - acc: 0.9231 - val_loss: 0.1790 - val_acc: 0.9278
# Epoch 28/200
# 22660/22660 [==============================] - 1s 35us/sample - loss: 0.1892 - acc: 0.9236 - val_loss: 0.1814 - val_acc: 0.9275
# Epoch 29/200
# 22660/22660 [==============================] - 1s 35us/sample - loss: 0.1844 - acc: 0.9252 - val_loss: 0.1796 - val_acc: 0.9283
# Epoch 30/200
# 22660/22660 [==============================] - 1s 36us/sample - loss: 0.1861 - acc: 0.9253 - val_loss: 0.1806 - val_acc: 0.9266
# Epoch 31/200
# 22660/22660 [==============================] - 1s 35us/sample - loss: 0.1841 - acc: 0.9248 - val_loss: 0.1810 - val_acc: 0.9261
# Epoch 32/200
# 22660/22660 [==============================] - 1s 32us/sample - loss: 0.1844 - acc: 0.9256 - val_loss: 0.1812 - val_acc: 0.9255
# Epoch 33/200
# 22660/22660 [==============================] - 1s 36us/sample - loss: 0.1850 - acc: 0.9248 - val_loss: 0.1779 - val_acc: 0.9275
# Epoch 34/200
# 22660/22660 [==============================] - 1s 32us/sample - loss: 0.1828 - acc: 0.9246 - val_loss: 0.1790 - val_acc: 0.9259
# Epoch 35/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1831 - acc: 0.9258 - val_loss: 0.1783 - val_acc: 0.9276
# Epoch 36/200
# 22660/22660 [==============================] - 1s 32us/sample - loss: 0.1820 - acc: 0.9264 - val_loss: 0.1792 - val_acc: 0.9266
# Epoch 37/200
# 22660/22660 [==============================] - 1s 32us/sample - loss: 0.1817 - acc: 0.9263 - val_loss: 0.1826 - val_acc: 0.9234
# Epoch 38/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1835 - acc: 0.9255 - val_loss: 0.1752 - val_acc: 0.9287
# Epoch 39/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1839 - acc: 0.9252 - val_loss: 0.1751 - val_acc: 0.9291
# Epoch 40/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1818 - acc: 0.9261 - val_loss: 0.1769 - val_acc: 0.9257
# Epoch 41/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1824 - acc: 0.9267 - val_loss: 0.1777 - val_acc: 0.9283
# Epoch 42/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1812 - acc: 0.9262 - val_loss: 0.1791 - val_acc: 0.9268
# Epoch 43/200
# 22660/22660 [==============================] - 1s 31us/sample - loss: 0.1790 - acc: 0.9273 - val_loss: 0.1761 - val_acc: 0.9296
# Epoch 44/200
# 22660/22660 [==============================] - 1s 35us/sample - loss: 0.1783 - acc: 0.9265 - val_loss: 0.1767 - val_acc: 0.9273
# Epoch 45/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1765 - acc: 0.9270 - val_loss: 0.1774 - val_acc: 0.9294
# Epoch 46/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1787 - acc: 0.9265 - val_loss: 0.1759 - val_acc: 0.9285
# Epoch 47/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1772 - acc: 0.9277 - val_loss: 0.1736 - val_acc: 0.9296
# Epoch 48/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1760 - acc: 0.9289 - val_loss: 0.1772 - val_acc: 0.9273
# Epoch 49/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1776 - acc: 0.9270 - val_loss: 0.1732 - val_acc: 0.9305
# Epoch 50/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1762 - acc: 0.9270 - val_loss: 0.1731 - val_acc: 0.9276
# Epoch 51/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1772 - acc: 0.9278 - val_loss: 0.1753 - val_acc: 0.9280
# Epoch 52/200
# 22660/22660 [==============================] - 1s 35us/sample - loss: 0.1757 - acc: 0.9276 - val_loss: 0.1769 - val_acc: 0.9285
# Epoch 53/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1760 - acc: 0.9283 - val_loss: 0.1740 - val_acc: 0.9298
# Epoch 54/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1771 - acc: 0.9280 - val_loss: 0.1767 - val_acc: 0.9282
# Epoch 55/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1740 - acc: 0.9289 - val_loss: 0.1731 - val_acc: 0.9296
# Epoch 56/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1738 - acc: 0.9284 - val_loss: 0.1774 - val_acc: 0.9259
# Epoch 57/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1739 - acc: 0.9277 - val_loss: 0.1769 - val_acc: 0.9287
# Epoch 58/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1758 - acc: 0.9278 - val_loss: 0.1757 - val_acc: 0.9299
# Epoch 59/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1717 - acc: 0.9289 - val_loss: 0.1748 - val_acc: 0.9291
# Epoch 60/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1740 - acc: 0.9296 - val_loss: 0.1735 - val_acc: 0.9303
# Epoch 61/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1732 - acc: 0.9286 - val_loss: 0.1788 - val_acc: 0.9289
# Epoch 62/200
# 22660/22660 [==============================] - 1s 34us/sample - loss: 0.1744 - acc: 0.9291 - val_loss: 0.1761 - val_acc: 0.9310
# Epoch 63/200
# 22660/22660 [==============================] - 1s 32us/sample - loss: 0.1734 - acc: 0.9295 - val_loss: 0.1720 - val_acc: 0.9296
# Epoch 64/200
# 22660/22660 [==============================] - 1s 33us/sample - loss: 0.1716 - acc: 0.9303 - val_loss: 0.1713 - val_acc: 0.9298
# Epoch 65/200
#  6912/22660 [========>.....................] - ETA: 0s - loss: 0.1641 - acc: 0.9343
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-510a55ef72d0> in <module>
#       1 set_lr(dense, 0.4e-3)
# ----> 2 dense.fit(aug_features,aug_y, epochs=200, batch_size=128, validation_split=0.2)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     778           validation_steps=validation_steps,
#     779           validation_freq=validation_freq,
# --> 780           steps_name='steps_per_epoch')
#     781
#     782   def evaluate(self,
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     361
#     362         # Get outputs.
# --> 363         batch_outs = f(ins_batch)
#     364         if not isinstance(batch_outs, list):
#     365           batch_outs = [batch_outs]
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# m = load_model()
m = get_resnet_model()
# m = get_model(dense=dense)
# m.summary()
# Out:
# 10 global res_blocks
# 7 local res_blocks

# %%
set_lr(m, 0.2e-3)

mycallback = LowerLr([5,5,5],[0.8e-3, 0.4e-4, 0.2e-4])

# (g_train_x, g_val_x), (l_train_x, l_val_x ), (train_y, val_y) = next(spliter)
m.fit([aug_g_x, aug_l_x], aug_y, epochs=15, batch_size=128, 
         validation_split=0.1, callbacks=[mycallback], verbose=1)
# Out:
# set learning rate to 0.00019999999494757503
# Train on 25493 samples, validate on 2833 samples
# Set Learning Rate: 0.0008
# Epoch 1/15
# 25493/25493 [==============================] - 13s 491us/sample - loss: 0.3823 - acc: 0.8938 - val_loss: 0.3630 - val_acc: 0.8987
# Epoch 2/15
# 25493/25493 [==============================] - 9s 357us/sample - loss: 0.2748 - acc: 0.9236 - val_loss: 0.2557 - val_acc: 0.9276
# Epoch 3/15
# 25493/25493 [==============================] - 9s 359us/sample - loss: 0.2420 - acc: 0.9337 - val_loss: 0.2469 - val_acc: 0.9287
# Epoch 4/15
# 25493/25493 [==============================] - 9s 358us/sample - loss: 0.2257 - acc: 0.9361 - val_loss: 0.2281 - val_acc: 0.9340
# Epoch 5/15
# 25493/25493 [==============================] - 9s 358us/sample - loss: 0.2098 - acc: 0.9401 - val_loss: 0.2317 - val_acc: 0.9312
# Set Learning Rate: 4e-05
# Epoch 6/15
# 25493/25493 [==============================] - 9s 359us/sample - loss: 0.1822 - acc: 0.9508 - val_loss: 0.2199 - val_acc: 0.9372
# Epoch 7/15
# 25493/25493 [==============================] - 9s 359us/sample - loss: 0.1765 - acc: 0.9528 - val_loss: 0.2206 - val_acc: 0.9365
# Epoch 8/15
# 25493/25493 [==============================] - 9s 360us/sample - loss: 0.1728 - acc: 0.9546 - val_loss: 0.2179 - val_acc: 0.9396
# Epoch 9/15
# 25493/25493 [==============================] - 9s 360us/sample - loss: 0.1694 - acc: 0.9562 - val_loss: 0.2166 - val_acc: 0.9379
# Epoch 10/15
# 25493/25493 [==============================] - 9s 360us/sample - loss: 0.1661 - acc: 0.9571 - val_loss: 0.2158 - val_acc: 0.9396
# Set Learning Rate: 2e-05
# Epoch 11/15
# 25493/25493 [==============================] - 9s 360us/sample - loss: 0.1623 - acc: 0.9589 - val_loss: 0.2187 - val_acc: 0.9358
# Epoch 12/15
# 25493/25493 [==============================] - 9s 360us/sample - loss: 0.1606 - acc: 0.9594 - val_loss: 0.2183 - val_acc: 0.9379
# Epoch 13/15
# 25493/25493 [==============================] - 9s 358us/sample - loss: 0.1587 - acc: 0.9603 - val_loss: 0.2202 - val_acc: 0.9351
# Epoch 14/15
# 25493/25493 [==============================] - 9s 360us/sample - loss: 0.1574 - acc: 0.9609 - val_loss: 0.2206 - val_acc: 0.9365
# Epoch 15/15
# 25493/25493 [==============================] - 9s 361us/sample - loss: 0.1557 - acc: 0.9617 - val_loss: 0.2199 - val_acc: 0.9379

# %%
plt.plot(m.history.history['val_loss'][0:-1], label='val_loss')
plt.plot(m.history.history['loss'][0:-1], label='train_loss')
plt.xlabel('Number of Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig(img_dir+'/train_val_loss.png', dpi=200)

# %%
plt.plot(m.history.history['acc'][:-1], label='train_acc')
plt.plot(m.history.history['val_acc'][:-1], label='val_acc')
plt.xlabel('Number of epoch')
plt.ylabel('Accuracy')
plt.title('Trend of Train and Validation Accuracy')
plt.legend()
plt.savefig('C:/Users/User/Desktop/Probation/train_val_acc.png', dpi=200)

# %%
# m = load_model()
m.evaluate([g_test_x, l_test_x], test_y)
dense.evaluate(test_features, test_y)
# save_model(m)
# save_model(dense, path="./models/dense.h5")
# save_train_test_data("C:/Users/User/dev/data/best/", *(g_train_x, l_train_x, train_y), *(g_test_x, l_test_x, test_y) )
# Out:
# 1574/1574 [==============================] - 1s 347us/sample - loss: 0.1960 - acc: 0.9479
# 1574/1574 [==============================] - 0s 102us/sample - loss: 0.1955 - acc: 0.9231
# [0.19551443415569683, 0.9231258]

# %%
2380/15737
# Out:
# 0.15123594077651395

# %%
pred = m.predict([g_test_x, l_test_x])

# %%
pred_class = np.where(pred[:,1]>0.5, 1, 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-91b75221b5c6> in <module>
# ----> 1 pred_class = np.where(pred[:,1]>0.5, 1, 0)
#
# NameError: name 'pred' is not defined

# %%
load_model()
# Out:
# W0903 00:27:31.366357 11848 deprecation.py:506] From c:\users\user\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0903 00:27:31.367357 11848 deprecation.py:506] From c:\users\user\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# loading model from C:\Users\User\dev\kepler\models\train.h5
# finished loading

# %%
# Out:
# '1.14.0'

# %%
sum(pred_class==test_y)/len(test_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-0ece6f530046> in <module>
# ----> 1 sum(pred_class==test_y)/len(test_y)
#
# NameError: name 'pred_class' is not defined

# %%
get_model_summary(m, [g_test_x, l_test_x, test_features], test_y, 0.5)
# Out:
# {'Accuracy': 0.9536213468869124,
#  'Precision': 0.8865979381443299,
#  'Recall': 0.9222520107238605,
#  'F1': 0.9040735873850196}

# %%
# plot the pie chart 
pred = m.predict([g_train_x, l_train_x, train_features])[:,1]

plt.figure(figsize=(8,8))
mask1 = pred < 0.20
mask2 = np.logical_and(pred >=0.20, pred < 0.5) 
mask3 = np.logical_and(pred >=0.5, pred < 0.6) 
mask4 = np.logical_and(pred >=0.6, pred < 0.8)
mask5 = np.logical_and(pred >=0.8, pred < 0.95)
mask6 = pred > 0.95

labels = ["[0, 0.2)", '[0.2, 0.5)', '[0.5, 0.6)','[0.6, 0.8)]', '[0.8, 0.95)', '[0.95, 1.0)']
sizes = [len(pred[mask1]),len(pred[mask2]),len(pred[mask3]),len(pred[mask4]), len(pred[mask5]), len(pred[mask6])]

labels = [f'{label} -- {sizes[i]/len(pred)*100:.2f}%' for i, label in enumerate(labels)]

patches, texts = plt.pie(sizes)
plt.legend(patches, labels, loc='best', bbox_to_anchor=(0.9, 1.),
           fontsize=14)
plt.tight_layout()

plt.savefig(img_dir + '/predict_percent.png', dpi=200, bbox_inches='tight')

# %%
plt.hist(pred, bins=50)
plt.savefig(img_dir + '/hist.png', dpi=200)

# %%
plt.hist(pred[pred < 0.5], bins=25)
plt.savefig(img_dir + '/hist_non_pc.png', dpi=200)

# %%
plt.hist(pred[pred >= 0.5], bins=25)
plt.savefig(img_dir + '/hist_pc.png', dpi=200)

# %%
x = np.linspace(0.01, 0.99, 30)
acc = []
precision = []
recall = [] 
f1 = []
for i, val in enumerate(x[:-1]):
    sys.stdout.write(f'\r {i+1}/{len(x[:-1])}')
    stats = get_model_summary(m, [g_test_x, l_test_x, test_features], test_y, val)
    acc.append(stats['Accuracy'])
    precision.append(stats['Precision'])
    recall.append(stats['Recall'])
    f1.append(stats['F1'])
# Out:
#  29/29

# %%
plt.figure(figsize=(10,6))
plt.plot(x[:-1], acc, 'o-', label='acc', ms=6.0, fillstyle='none')
plt.plot(x[:-1], precision,  's-', label='precision',ms=6.0, fillstyle='none')
plt.plot(x[:-1], recall, '^-', label='recall',ms=6.0, fillstyle='none')
plt.plot(x[:-1], f1,'+-', label='f1',ms=6.0, fillstyle='none' )

plt.ylabel('Value')
plt.xlabel('Threshold')
plt.legend()
plt.savefig(img_dir+"/stats_vs_threshold.png", dpi=200)

# %%
plt.figure(figsize=(8,5))
plt.plot(recall, precision, 's-', label='Value', ms=6.0, fillstyle='none')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
plt.savefig(img_dir+'/precision_vs_recall.png', dpi=200)

# %%
# m.evaluate([g_train_x, l_train_x, train_features], train_y)

# %%
# m = load_model()
# Out:
# W0901 22:27:10.438807  1724 deprecation.py:506] From c:\users\user\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0901 22:27:10.440843  1724 deprecation.py:506] From c:\users\user\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0901 22:27:10.443807  1724 deprecation.py:506] From c:\users\user\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# loading model from C:\Users\User\dev\kepler\models\train.h5
# Error loading model from C:\Users\User\dev\kepler\models\train.h5
# "Unable to open object (object 'dense_101' doesn't exist)"

# %%
x, y = get_roc(m, [g_test_x, l_test_x, test_features], test_y)

# %%
auc(x, y)
# Out:
# 0.9772747683872187

# %%
from dr25 import *

# %%
test_kepid(m, '6062088', dr24=1)
# Out:
# {1: 0.12890472, 2: 0.014122308, 3: 0.0111561585}

# %%
plt.plot(get_binned_normalized_flux_by_IDs('1161345', overwrite=1)[0][0])
# Out:
#  100.00%

# %%
test_kepid(m, '6062088', dr24=1)
# Out:
# {1: 0.041364755, 2: 0.0069882427, 3: 0.0073068514}

# %%
from presentation.utils import block

# %%
plt.plot(block(get_binned_normalized_flux_by_IDs('6062088', overwrite=0)[0][0], 50, 100), '.')
# Out:
#  100.00%

# %%
plt.plot(get_binned_normalized_flux_by_IDs('5956342', overwrite=0)[0][0], '.')
# Out:
#  100.00%

# %%
plt.plot(get_binned_local_view_by_IDs('6062088', overwrite=1)[0][0])
# Out:
# loading 1/1

# %%
f = get_binned_normalized_flux_by_IDs('892772', overwrite=1)[1]
f
# Out:
#  100.00%
# array([[-0.04303355, -0.03993297, -0.04004691, ..., -0.21785278,
#         -0.43912435, -0.28509838]])

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Bin')
plt.ylabel('Normalized Flux')
plt.title('Global View of 00892772')
plt.plot(f[0], '.', lw=0.5, color='k', ms=3.0)
plt.savefig(img_dir+'/892772_fp_dot.png', dpi=200)

# %%
local = get_binned_local_view_by_IDs('892772', overwrite=1)[1]
# Out:
# loading 1/1

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Bin')
plt.ylabel('Normalized Flux')
plt.title('Local View of 00892772')
plt.plot(local[0], lw=1.0, color='k')
plt.savefig(img_dir+'/892772_local_fp.png', dpi=200)

# %%
m.evaluate([g_train_x, l_train_x], train_y)
# Out:
# 14163/14163 [==============================] - 4s 259us/sample - loss: 0.1411 - acc: 0.9883
# [0.14114456367864706, 0.9883499]

# %%
g_pc = np.loadtxt(data_dir + '/all_PCs_flux.txt')
l_pc = np.loadtxt(data_dir + '/local_all_PCs_flux.txt')

g_pc=g_pc.reshape(*g_pc.shape, 1) 
l_pc=l_pc.reshape(*l_pc.shape, 1)

# %%
g_non  = np.loadtxt(data_dir + '/all_Non_PCs_flux.txt')
l_non  = np.loadtxt(data_dir + '/local_all_Non_PCs_flux.txt')

g_non =g_non.reshape(*g_non.shape, 1) 
l_non =l_non.reshape(*l_non.shape, 1)

# %%
np.concatenate([g_pc, g_non]).shape,np.concatenate([l_pc, l_non]).shape
# Out:
# ((15737, 2001, 1), (15737, 201, 1))

# %%
m.evaluate([np.concatenate([g_pc, g_non]), np.concatenate([l_pc, l_non])],
    np.concatenate([np.ones(3600), np.zeros(len(g_non))]))
# Out:
# 15737/15737 [==============================] - ETA: 4:05 - loss: 0.0670 - acc: 1.000 - ETA: 44s - loss: 0.1437 - acc: 0.958 - ETA: 26s - loss: 0.1595 - acc: 0.95 - ETA: 19s - loss: 0.1592 - acc: 0.95 - ETA: 15s - loss: 0.1684 - acc: 0.95 - ETA: 13s - loss: 0.1671 - acc: 0.95 - ETA: 12s - loss: 0.1675 - acc: 0.95 - ETA: 10s - loss: 0.1638 - acc: 0.95 - ETA: 9s - loss: 0.1647 - acc: 0.9554 - ETA: 9s - loss: 0.1848 - acc: 0.954 - ETA: 8s - loss: 0.1815 - acc: 0.955 - ETA: 7s - loss: 0.1786 - acc: 0.954 - ETA: 7s - loss: 0.1802 - acc: 0.951 - ETA: 7s - loss: 0.1809 - acc: 0.949 - ETA: 6s - loss: 0.1839 - acc: 0.947 - ETA: 6s - loss: 0.1883 - acc: 0.946 - ETA: 6s - loss: 0.1876 - acc: 0.947 - ETA: 5s - loss: 0.1885 - acc: 0.948 - ETA: 5s - loss: 0.1866 - acc: 0.949 - ETA: 5s - loss: 0.1888 - acc: 0.948 - ETA: 5s - loss: 0.1950 - acc: 0.946 - ETA: 5s - loss: 0.1876 - acc: 0.949 - ETA: 5s - loss: 0.1816 - acc: 0.951 - ETA: 4s - loss: 0.1749 - acc: 0.953 - ETA: 4s - loss: 0.1688 - acc: 0.955 - ETA: 4s - loss: 0.1638 - acc: 0.957 - ETA: 4s - loss: 0.1586 - acc: 0.958 - ETA: 4s - loss: 0.1540 - acc: 0.960 - ETA: 4s - loss: 0.1497 - acc: 0.961 - ETA: 4s - loss: 0.1457 - acc: 0.963 - ETA: 4s - loss: 0.1418 - acc: 0.964 - ETA: 3s - loss: 0.1383 - acc: 0.965 - ETA: 3s - loss: 0.1350 - acc: 0.966 - ETA: 3s - loss: 0.1318 - acc: 0.967 - ETA: 3s - loss: 0.1293 - acc: 0.968 - ETA: 3s - loss: 0.1269 - acc: 0.969 - ETA: 3s - loss: 0.1245 - acc: 0.970 - ETA: 3s - loss: 0.1219 - acc: 0.971 - ETA: 3s - loss: 0.1196 - acc: 0.971 - ETA: 3s - loss: 0.1175 - acc: 0.972 - ETA: 3s - loss: 0.1155 - acc: 0.973 - ETA: 3s - loss: 0.1135 - acc: 0.974 - ETA: 2s - loss: 0.1116 - acc: 0.974 - ETA: 2s - loss: 0.1098 - acc: 0.975 - ETA: 2s - loss: 0.1081 - acc: 0.975 - ETA: 2s - loss: 0.1065 - acc: 0.976 - ETA: 2s - loss: 0.1051 - acc: 0.976 - ETA: 2s - loss: 0.1035 - acc: 0.977 - ETA: 2s - loss: 0.1023 - acc: 0.977 - ETA: 2s - loss: 0.1009 - acc: 0.978 - ETA: 2s - loss: 0.1001 - acc: 0.978 - ETA: 2s - loss: 0.0991 - acc: 0.978 - ETA: 2s - loss: 0.0984 - acc: 0.978 - ETA: 2s - loss: 0.0973 - acc: 0.979 - ETA: 2s - loss: 0.0963 - acc: 0.979 - ETA: 1s - loss: 0.0953 - acc: 0.979 - ETA: 1s - loss: 0.0943 - acc: 0.980 - ETA: 1s - loss: 0.0933 - acc: 0.980 - ETA: 1s - loss: 0.0922 - acc: 0.980 - ETA: 1s - loss: 0.0912 - acc: 0.981 - ETA: 1s - loss: 0.0904 - acc: 0.981 - ETA: 1s - loss: 0.0896 - acc: 0.981 - ETA: 1s - loss: 0.0888 - acc: 0.982 - ETA: 1s - loss: 0.0879 - acc: 0.982 - ETA: 1s - loss: 0.0877 - acc: 0.982 - ETA: 1s - loss: 0.0869 - acc: 0.982 - ETA: 1s - loss: 0.0861 - acc: 0.982 - ETA: 1s - loss: 0.0853 - acc: 0.983 - ETA: 1s - loss: 0.0850 - acc: 0.983 - ETA: 1s - loss: 0.0843 - acc: 0.983 - ETA: 0s - loss: 0.0838 - acc: 0.983 - ETA: 0s - loss: 0.0834 - acc: 0.983 - ETA: 0s - loss: 0.0827 - acc: 0.984 - ETA: 0s - loss: 0.0820 - acc: 0.984 - ETA: 0s - loss: 0.0814 - acc: 0.984 - ETA: 0s - loss: 0.0808 - acc: 0.984 - ETA: 0s - loss: 0.0803 - acc: 0.984 - ETA: 0s - loss: 0.0798 - acc: 0.984 - ETA: 0s - loss: 0.0793 - acc: 0.985 - ETA: 0s - loss: 0.0789 - acc: 0.985 - ETA: 0s - loss: 0.0784 - acc: 0.985 - ETA: 0s - loss: 0.0778 - acc: 0.985 - ETA: 0s - loss: 0.0774 - acc: 0.985 - ETA: 0s - loss: 0.0771 - acc: 0.985 - ETA: 0s - loss: 0.0767 - acc: 0.985 - ETA: 0s - loss: 0.0762 - acc: 0.986 - 5s 337us/sample - loss: 0.0760 - acc: 0.9860
# [0.07602200746491751, 0.9860202]

# %%
m.evaluate([g_non, l_non], np.zeros(len(g_non)))
# Out:
# 12137/12137 [==============================] - ETA: 3s - loss: 0.0353 - acc: 1.000 - ETA: 3s - loss: 0.0353 - acc: 1.000 - ETA: 3s - loss: 0.0499 - acc: 0.994 - ETA: 3s - loss: 0.0462 - acc: 0.996 - ETA: 3s - loss: 0.0435 - acc: 0.997 - ETA: 3s - loss: 0.0432 - acc: 0.997 - ETA: 3s - loss: 0.0442 - acc: 0.997 - ETA: 3s - loss: 0.0429 - acc: 0.997 - ETA: 3s - loss: 0.0427 - acc: 0.997 - ETA: 3s - loss: 0.0424 - acc: 0.997 - ETA: 3s - loss: 0.0418 - acc: 0.997 - ETA: 3s - loss: 0.0414 - acc: 0.997 - ETA: 3s - loss: 0.0410 - acc: 0.998 - ETA: 3s - loss: 0.0404 - acc: 0.998 - ETA: 3s - loss: 0.0401 - acc: 0.998 - ETA: 2s - loss: 0.0398 - acc: 0.998 - ETA: 2s - loss: 0.0395 - acc: 0.998 - ETA: 2s - loss: 0.0405 - acc: 0.998 - ETA: 2s - loss: 0.0403 - acc: 0.998 - ETA: 2s - loss: 0.0400 - acc: 0.998 - ETA: 2s - loss: 0.0400 - acc: 0.998 - ETA: 2s - loss: 0.0401 - acc: 0.998 - ETA: 2s - loss: 0.0399 - acc: 0.998 - ETA: 2s - loss: 0.0397 - acc: 0.998 - ETA: 2s - loss: 0.0397 - acc: 0.998 - ETA: 2s - loss: 0.0395 - acc: 0.998 - ETA: 2s - loss: 0.0395 - acc: 0.998 - ETA: 2s - loss: 0.0393 - acc: 0.998 - ETA: 2s - loss: 0.0394 - acc: 0.998 - ETA: 2s - loss: 0.0394 - acc: 0.998 - ETA: 2s - loss: 0.0397 - acc: 0.998 - ETA: 2s - loss: 0.0396 - acc: 0.998 - ETA: 2s - loss: 0.0399 - acc: 0.998 - ETA: 1s - loss: 0.0400 - acc: 0.998 - ETA: 1s - loss: 0.0405 - acc: 0.998 - ETA: 1s - loss: 0.0404 - acc: 0.998 - ETA: 1s - loss: 0.0404 - acc: 0.998 - ETA: 1s - loss: 0.0405 - acc: 0.998 - ETA: 1s - loss: 0.0404 - acc: 0.998 - ETA: 1s - loss: 0.0403 - acc: 0.998 - ETA: 1s - loss: 0.0402 - acc: 0.998 - ETA: 1s - loss: 0.0401 - acc: 0.998 - ETA: 1s - loss: 0.0404 - acc: 0.998 - ETA: 1s - loss: 0.0404 - acc: 0.998 - ETA: 1s - loss: 0.0402 - acc: 0.998 - ETA: 1s - loss: 0.0409 - acc: 0.998 - ETA: 1s - loss: 0.0409 - acc: 0.998 - ETA: 1s - loss: 0.0408 - acc: 0.998 - ETA: 1s - loss: 0.0408 - acc: 0.998 - ETA: 1s - loss: 0.0407 - acc: 0.998 - ETA: 0s - loss: 0.0409 - acc: 0.997 - ETA: 0s - loss: 0.0409 - acc: 0.997 - ETA: 0s - loss: 0.0408 - acc: 0.997 - ETA: 0s - loss: 0.0410 - acc: 0.997 - ETA: 0s - loss: 0.0412 - acc: 0.997 - ETA: 0s - loss: 0.0411 - acc: 0.997 - ETA: 0s - loss: 0.0411 - acc: 0.997 - ETA: 0s - loss: 0.0410 - acc: 0.997 - ETA: 0s - loss: 0.0409 - acc: 0.997 - ETA: 0s - loss: 0.0408 - acc: 0.997 - ETA: 0s - loss: 0.0407 - acc: 0.997 - ETA: 0s - loss: 0.0407 - acc: 0.997 - ETA: 0s - loss: 0.0406 - acc: 0.997 - ETA: 0s - loss: 0.0405 - acc: 0.998 - ETA: 0s - loss: 0.0406 - acc: 0.997 - ETA: 0s - loss: 0.0408 - acc: 0.997 - ETA: 0s - loss: 0.0408 - acc: 0.997 - 4s 309us/sample - loss: 0.0407 - acc: 0.9977
# [0.04072166560866142, 0.997693]

# %%
df[df['kepid']==4661634]
# Out:
#         kepid  tce_plnt_num  tce_rogue_flag  tce_period  tce_period_err  \
# 2450  4661634             1             NaN     73.8942        0.000005
# 2451  4661634             2             NaN     73.8944        0.000050
#
#       tce_time0bk  tce_time0bk_err  tce_impact  tce_impact_err  tce_duration  \
# 2450      159.901         0.000054      0.2543        0.002043         9.496
# 2451      142.939         0.000590      0.7741        0.002891        12.320
#
#       tce_duration_err  tce_depth  tce_depth_err av_training_set
# 2450          0.003661   217700.0          72.38             AFP
# 2451          0.034720    22720.0          59.92             AFP

# %%
g = get_binned_normalized_flux_by_IDs('4661634', overwrite=1)[1][0]
g = g.reshape(*g.shape, 1)
# Out:
#  100.00%

# %%
l = get_binned_local_view_by_IDs('4661634', overwrite=1)[1][0]
# Out:
# loading 1/1

# %%
get_binned_normalized_PC_flux(2, return_kepids=1, overwrite=0)
# Out:
#  100.00%
# (array([[-0.02869911, -0.03458117, -0.03357613, ..., -0.0522324 ,
#           0.10145352,  0.02323417],
#         [ 0.12723104,  0.02387044, -0.05180007, ..., -0.06799214,
#          -0.12016237,  0.13925874],
#         [-0.06642725, -0.07693028,  0.06105036, ..., -0.00718474,
#          -0.06202927,  0.05778516],
#         [-0.01670242, -0.00458813, -0.01932849, ...,  0.02437321,
#          -0.02259685,  0.02511374]]), ['010166274', '010330115'])

# %%
get_binned_normalized_flux_by_IDs('010166274', overwrite=1)[0]
# Out:
#  100.00%
# array([[-0.02869911, -0.03458117, -0.03357613, ..., -0.0522324 ,
#          0.10145352,  0.02323417],
#        [ 0.12723104,  0.02387044, -0.05180007, ..., -0.06799214,
#         -0.12016237,  0.13925874],
#        [-0.06642725, -0.07693028,  0.06105036, ..., -0.00718474,
#         -0.06202927,  0.05778516]])

# %%
m.predict([g1, l1])
# Out:
# array([[0.14455462, 0.8554454 ]], dtype=float32)

# %%
m.predict([g_train_x[9164].reshape(1,2001,1), l_train_x[9164].reshape(1,201,1)])
# Out:
# array([[0.9891412 , 0.01085873]], dtype=float32)

# %%
for i, row in enumerate(l_train_x):
    row = row.reshape(1, *row.shape)
    if np.max(np.abs(row-l1))<1e-2:
        print(i)

# %%
plt.plot(l1.ravel())

# %%
plt.plot(l_train_x[9164].ravel())

# %%
g1, l1 = test_kepid(m, '10006096', dr24=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-140-eeed472a290d> in <module>
# ----> 1 g1, l1 = test_kepid(m, '10006096', dr24=1)
#
# ~\dev\kepler\dr25\gen_flux_txt.py in test_kepid(model, kepid, params, verbose, dr24)
#     154
#     155             local_flux = process_local(
# --> 156                 time, flux, period, t0, duration
#     157             )
#     158             # reshape flux
#
# ~\dev\kepler\utils\functions.py in process_local(time, flux, period, t0, duration)
#     177         time, flux,
#     178         num_bins=num_local_bins,
# --> 179         bin_width=bin_width
#     180     )
#     181
#
# ~\dev\kepler\utils\bin.py in median_bin(x, y, num_bins, bin_width, normalize)
#       8     bin_width is the scale factor of (x_max-x_min)/num_bins, not the absolute value
#       9     """
# ---> 10     x_min, x_max = x[0], x[-1]
#      11     default_bin_width = (x_max - x_min) / num_bins
#      12     bin_width = default_bin_width if bin_width is None else bin_width
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
get_summary_by_IDs('10006096')
# Out:
# {
#   "period": [
#     [
#       "0",
#       70.516
#     ],
#     [
#       "0",
#       70.5199
#     ]
#   ],
#   "tce duration": [
#     [
#       "0",
#       0.10416666666666667
#     ],
#     [
#       "0",
#       1.6591666666666667
#     ]
#   ],
#   "tce epoch": [
#     [
#       "0",
#       142.86
#     ],
#     [
#       "0",
#       143.06
#     ]
#   ]
# }

# %%
time, flux = get_time_flux_by_ID('10006096')

# %%
curtime, curflux = remove_points_other_tce(time, flux , 70.516, [70.516, 70.5199], [142.86, 143.06], 
                        [0.10416666666666667, 1.6591666666666667])

# %%
t, f = fold(curtime, curflux,70.516, 142.86%70.516,)

# %%
plt.plot(t,f )

# %%
choose_from_center(t, 70.516/2, 4 *0.10416666666666667)
# Out:
# (32162, 32162)
